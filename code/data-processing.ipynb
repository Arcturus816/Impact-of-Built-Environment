# %% [markdown]
# # Data processing
#
# This Jupyter notebook will explain our data processing.

# %%
# Import modules
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Read in Kaggle data
kaggle_df = pd.read_csv("../data/raw/Kaggle/US_Accidents_March23_sampled_500k.csv")
kaggle_df
# Out:
#                ID   Source  Severity                     Start_Time  \
# 0       A-2047758  Source2         2            2019-06-12 10:10:56
# 1       A-4694324  Source1         2  2022-12-03 23:37:14.000000000
# 2       A-5006183  Source1         2  2022-08-20 13:13:00.000000000
# 3       A-4237356  Source1         2            2022-02-21 17:43:04
# 4       A-6690583  Source1         2            2020-12-04 01:46:00
# ...           ...      ...       ...                            ...
# 499995  A-6077227  Source1         2            2021-12-15 07:30:00
# 499996  A-6323243  Source1         2            2021-12-19 16:25:00
# 499997  A-3789256  Source1         2            2022-04-13 19:28:29
# 499998  A-7030381  Source1         3            2020-05-15 17:20:56
# 499999  A-5438901  Source1         2            2022-04-02 23:23:13
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 0                 2019-06-12 10:55:58  30.641211  -91.153481        NaN
# ...

# %%
# Read in EPA data
epa_gdf = gpd.read_file("../data/raw/EPA/SmartLocationDatabaseV3/SmartLocationDatabase.gdb")
epa_gdf
# Out:
#              GEOID10       GEOID20 STATEFP COUNTYFP TRACTCE BLKGRPCE   CSA  \
# 0       481130078254  481130078254      48      113  007825        4   206
# 1       481130078252  481130078252      48      113  007825        2   206
# 2       481130078253  481130078253      48      113  007825        3   206
# 3       481130078241  481130078241      48      113  007824        1   206
# 4       481130078242  481130078242      48      113  007824        2   206
# ...              ...           ...     ...      ...     ...      ...   ...
# 220734  780309610002  780309610002      78      030  961000        2  None
# 220735  780309610003  780309610003      78      030  961000        3  None
# 220736  780309610005  780309610005      78      030  961000        5  None
# 220737  780309607003  780309607003      78      030  960700        3  None
# 220738  780309602002  780309602002      78      030  960200        2  None
#
# ...

# %% [markdown]
# ## Combining the two data sets
#
# We will combine our two data sets using spatial join.

# %%
# First, find CRS from EPA data set
epa_crs = epa_gdf.crs
epa_crs
# Out:
# <Projected CRS: ESRI:102039>
# Name: USA_Contiguous_Albers_Equal_Area_Conic_USGS_version
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
kaggle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     500000 non-null  object
#  1   Source                 500000 non-null  object
#  2   Severity               500000 non-null  int64
#  3   Start_Time             500000 non-null  object
#  4   End_Time               500000 non-null  object
#  5   Start_Lat              500000 non-null  float64
#  6   Start_Lng              500000 non-null  float64
#  7   End_Lat                279623 non-null  float64
#  8   End_Lng                279623 non-null  float64
#  9   Distance(mi)           500000 non-null  float64
#  10  Description            499999 non-null  object
#  11  Street                 499309 non-null  object
#  12  City                   499981 non-null  object
#  13  County                 500000 non-null  object
# ...

# %%
# Convert Kaggle data set to GeoDataFrame
kaggle_gdf = gpd.GeoDataFrame(kaggle_df, 
                              geometry=gpd.points_from_xy(kaggle_df.Start_Lng, kaggle_df.Start_Lat), 
                              crs = "EPSG:4326") # World geodetic system, see https://epsg.io/4326
kaggle_gdf
# Out:
#                ID   Source  Severity                     Start_Time  \
# 0       A-2047758  Source2         2            2019-06-12 10:10:56
# 1       A-4694324  Source1         2  2022-12-03 23:37:14.000000000
# 2       A-5006183  Source1         2  2022-08-20 13:13:00.000000000
# 3       A-4237356  Source1         2            2022-02-21 17:43:04
# 4       A-6690583  Source1         2            2020-12-04 01:46:00
# ...           ...      ...       ...                            ...
# 499995  A-6077227  Source1         2            2021-12-15 07:30:00
# 499996  A-6323243  Source1         2            2021-12-19 16:25:00
# 499997  A-3789256  Source1         2            2022-04-13 19:28:29
# 499998  A-7030381  Source1         3            2020-05-15 17:20:56
# 499999  A-5438901  Source1         2            2022-04-02 23:23:13
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 0                 2019-06-12 10:55:58  30.641211  -91.153481        NaN
# ...

# %%
kaggle_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Convert Kaggle GDF to same CRS as EPA GDF
kaggle2_gdf = kaggle_gdf.to_crs(crs=epa_crs)
kaggle2_gdf
# Out:
#                ID   Source  Severity                     Start_Time  \
# 0       A-2047758  Source2         2            2019-06-12 10:10:56
# 1       A-4694324  Source1         2  2022-12-03 23:37:14.000000000
# 2       A-5006183  Source1         2  2022-08-20 13:13:00.000000000
# 3       A-4237356  Source1         2            2022-02-21 17:43:04
# 4       A-6690583  Source1         2            2020-12-04 01:46:00
# ...           ...      ...       ...                            ...
# 499995  A-6077227  Source1         2            2021-12-15 07:30:00
# 499996  A-6323243  Source1         2            2021-12-19 16:25:00
# 499997  A-3789256  Source1         2            2022-04-13 19:28:29
# 499998  A-7030381  Source1         3            2020-05-15 17:20:56
# 499999  A-5438901  Source1         2            2022-04-02 23:23:13
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 0                 2019-06-12 10:55:58  30.641211  -91.153481        NaN
# ...

# %%
# Let's see if the geometry makes sense
fig, ax = plt.subplots()
#epa_gdf.plot(ax=ax, color="white", edgecolor="black")
epa_gdf.plot(ax=ax)
kaggle2_gdf.plot(ax=ax, color="red", alpha=0.005)
plt.show()

# %%
# Combine with spatial join, keeping geometry from EPA data
combined_gdf = epa_gdf.sjoin(kaggle2_gdf, how="inner")
combined_gdf
# Out:
#              GEOID10       GEOID20 STATEFP COUNTYFP TRACTCE BLKGRPCE   CSA  \
# 0       481130078254  481130078254      48      113  007825        4   206
# 0       481130078254  481130078254      48      113  007825        4   206
# 0       481130078254  481130078254      48      113  007825        4   206
# 0       481130078254  481130078254      48      113  007825        4   206
# 0       481130078254  481130078254      48      113  007825        4   206
# ...              ...           ...     ...      ...     ...      ...   ...
# 217713  560210004015  560210004015      56      021  000401        5  None
# 217713  560210004015  560210004015      56      021  000401        5  None
# 217714  560210019013  560210019013      56      021  001901        3  None
# 217723  560210004014  560210004014      56      021  000401        4  None
# 217728  560210004022  560210004022      56      021  000402        2  None
#
# ...

# %%
cols = list(combined_gdf.columns)
cols
# Out:
# ['GEOID10',
#  'GEOID20',
#  'STATEFP',
#  'COUNTYFP',
#  'TRACTCE',
#  'BLKGRPCE',
#  'CSA',
#  'CSA_Name',
#  'CBSA',
#  'CBSA_Name',
#  'CBSA_POP',
#  'CBSA_EMP',
#  'CBSA_WRK',
#  'Ac_Total',
#  'Ac_Water',
#  'Ac_Land',
#  'Ac_Unpr',
#  'TotPop',
#  'CountHU',
#  'HH',
#  'P_WrkAge',
#  'AutoOwn0',
#  'Pct_AO0',
#  'AutoOwn1',
#  'Pct_AO1',
#  'AutoOwn2p',
#  'Pct_AO2p',
#  'Workers',
#  'R_LowWageWk',
#  'R_MedWageWk',
#  'R_HiWageWk',
#  'R_PCTLOWWAGE',
#  'TotEmp',
#  'E5_Ret',
#  'E5_Off',
#  'E5_Ind',
#  'E5_Svc',
#  'E5_Ent',
#  'E8_Ret',
#  'E8_off',
#  'E8_Ind',
#  'E8_Svc',
#  'E8_Ent',
#  'E8_Ed',
#  'E8_Hlth',
#  'E8_Pub',
#  'E_LowWageWk',
#  'E_MedWageWk',
#  'E_HiWageWk',
#  'E_PctLowWage',
#  'D1A',
#  'D1B',
#  'D1C',
#  'D1C5_RET',
#  'D1C5_OFF',
#  'D1C5_IND',
#  'D1C5_SVC',
#  'D1C5_ENT',
#  'D1C8_RET',
#  'D1C8_OFF',
#  'D1C8_IND',
#  'D1C8_SVC',
#  'D1C8_ENT',
#  'D1C8_ED',
#  'D1C8_HLTH',
#  'D1C8_PUB',
#  'D1D',
#  'D1_FLAG',
#  'D2A_JPHH',
# ...

# %%
epa_cols = list(epa_gdf.columns)
reordered_cols = list(kaggle_df.columns)
reordered_cols.extend(epa_cols)
reordered_cols.insert(0, "index_right")
reordered_cols
# Out:
# ['index_right',
#  'ID',
#  'Source',
#  'Severity',
#  'Start_Time',
#  'End_Time',
#  'Start_Lat',
#  'Start_Lng',
#  'End_Lat',
#  'End_Lng',
#  'Distance(mi)',
#  'Description',
#  'Street',
#  'City',
#  'County',
#  'State',
#  'Zipcode',
#  'Country',
#  'Timezone',
#  'Airport_Code',
#  'Weather_Timestamp',
#  'Temperature(F)',
#  'Wind_Chill(F)',
#  'Humidity(%)',
#  'Pressure(in)',
#  'Visibility(mi)',
#  'Wind_Direction',
#  'Wind_Speed(mph)',
#  'Precipitation(in)',
#  'Weather_Condition',
#  'Amenity',
#  'Bump',
#  'Crossing',
#  'Give_Way',
#  'Junction',
#  'No_Exit',
#  'Railway',
#  'Roundabout',
#  'Station',
#  'Stop',
#  'Traffic_Calming',
#  'Traffic_Signal',
#  'Turning_Loop',
#  'Sunrise_Sunset',
#  'Civil_Twilight',
#  'Nautical_Twilight',
#  'Astronomical_Twilight',
#  'GEOID10',
#  'GEOID20',
#  'STATEFP',
#  'COUNTYFP',
#  'TRACTCE',
#  'BLKGRPCE',
#  'CSA',
#  'CSA_Name',
#  'CBSA',
#  'CBSA_Name',
#  'CBSA_POP',
#  'CBSA_EMP',
#  'CBSA_WRK',
# ...

# %%
reordered_gdf = combined_gdf[reordered_cols]
reordered_gdf
# Out:
#         index_right         ID   Source  Severity  \
# 0             83717  A-6795604  Source1         2
# 0            324653  A-6234096  Source1         2
# 0            165637   A-453264  Source2         2
# 0              1572   A-451832  Source2         2
# 0            111297  A-6221742  Source1         2
# ...             ...        ...      ...       ...
# 217713       374946  A-4124562  Source1         2
# 217713       177788  A-5117079  Source1         2
# 217714       131209  A-5417474  Source1         2
# 217723        11571  A-3435528  Source1         2
# 217728        55061  A-5589792  Source1         2
#
#                            Start_Time                       End_Time  \
# 0                 2020-11-27 15:24:18            2020-11-27 17:42:19
# 0                 2021-11-14 18:51:42            2021-11-14 20:26:09
# 0                 2017-05-24 08:54:57            2017-05-24 09:39:33
# 0                 2017-05-17 07:57:33            2017-05-17 09:12:20
# ...

# %%
sorted_gdf = reordered_gdf.sort_values(by="index_right")
sorted_gdf
# Out:
#         index_right         ID   Source  Severity  \
# 105197            0  A-2047758  Source2         2
# 19445             1  A-4694324  Source1         2
# 37731             2  A-5006183  Source1         2
# 128051            3  A-4237356  Source1         2
# 33987             4  A-6690583  Source1         2
# ...             ...        ...      ...       ...
# 184267       499995  A-6077227  Source1         2
# 71798        499996  A-6323243  Source1         2
# 27121        499997  A-3789256  Source1         2
# 16871        499998  A-7030381  Source1         3
# 202260       499999  A-5438901  Source1         2
#
#                            Start_Time                       End_Time  \
# 105197            2019-06-12 10:10:56            2019-06-12 10:55:58
# 19445   2022-12-03 23:37:14.000000000  2022-12-04 01:56:53.000000000
# 37731   2022-08-20 13:13:00.000000000  2022-08-20 15:22:45.000000000
# 128051            2022-02-21 17:43:04            2022-02-21 19:43:23
# ...

# %%
reindexed_gdf = sorted_gdf.reset_index(drop=True)
reindexed_gdf
# Out:
#         index_right         ID   Source  Severity  \
# 0                 0  A-2047758  Source2         2
# 1                 1  A-4694324  Source1         2
# 2                 2  A-5006183  Source1         2
# 3                 3  A-4237356  Source1         2
# 4                 4  A-6690583  Source1         2
# ...             ...        ...      ...       ...
# 499995       499995  A-6077227  Source1         2
# 499996       499996  A-6323243  Source1         2
# 499997       499997  A-3789256  Source1         2
# 499998       499998  A-7030381  Source1         3
# 499999       499999  A-5438901  Source1         2
#
#                            Start_Time                       End_Time  \
# 0                 2019-06-12 10:10:56            2019-06-12 10:55:58
# 1       2022-12-03 23:37:14.000000000  2022-12-04 01:56:53.000000000
# 2       2022-08-20 13:13:00.000000000  2022-08-20 15:22:45.000000000
# 3                 2022-02-21 17:43:04            2022-02-21 19:43:23
# ...

# %%
combined2_gdf = reindexed_gdf.drop(columns=["index_right"])
combined2_gdf
# Out:
#                ID   Source  Severity                     Start_Time  \
# 0       A-2047758  Source2         2            2019-06-12 10:10:56
# 1       A-4694324  Source1         2  2022-12-03 23:37:14.000000000
# 2       A-5006183  Source1         2  2022-08-20 13:13:00.000000000
# 3       A-4237356  Source1         2            2022-02-21 17:43:04
# 4       A-6690583  Source1         2            2020-12-04 01:46:00
# ...           ...      ...       ...                            ...
# 499995  A-6077227  Source1         2            2021-12-15 07:30:00
# 499996  A-6323243  Source1         2            2021-12-19 16:25:00
# 499997  A-3789256  Source1         2            2022-04-13 19:28:29
# 499998  A-7030381  Source1         3            2020-05-15 17:20:56
# 499999  A-5438901  Source1         2            2022-04-02 23:23:13
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 0                 2019-06-12 10:55:58  30.641211  -91.153481        NaN
# ...

# %% [markdown]
# Now that we have successfully combined the two data sets, it seems like a good idea to save our data.

# %%
# Save as file geodatabase, since that is how the original EPA data was formatted
combined2_gdf.to_file("../data/processed/combined.gdb", driver="OpenFileGDB")
# Out:
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Severity of type Integer64 will be written as a Float64. To get Integer64, use layer creation option TARGET_ARCGIS_VERSION=ARCGIS_PRO_3_2_OR_LATER
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Distance(mi)' to 'Distance_mi_'
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Temperature(F)' to 'Temperature_F_'
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Wind_Chill(F)' to 'Wind_Chill_F_'
#   ogr_write(
# ...

# %% [markdown]
# ## Filtering by counties
#
# Right now, `combined.gdb` is 2.13 GB. Github has a 2 GB push limit and 100 MiB file size limit, so we want to shrink our data.
#
# We will focus on counties in California that have sufficiently high population density.
# For reference, [World Population Review](https://web.archive.org/web/20250321211127/https://worldpopulationreview.com/us-counties/california) uses UC Census data to provide interactive lists and maps of counties based on population and density.
#
# Selecting the top 9 counties by population density will allow us to keep San Diego, so let's try that idea first.
# 1. San Francisco County (FIPS = `075`)
# 2. Orange County (FIPS = `059`)
# 3. Los Angeles County (FIPS = `037`)
# 4. Alameda County (FIPS = `001`)
# 5. Sacramento County (FIPS = `067`)
# 6. San Mateo County (FIPS = `081`)
# 7. Contra Costa County (FIPS = `013`)
# 8. Santa Clara County (FIPS = `085`)
# 9. San Diego County (FIPS = `073`)

# %%
california_gdf = combined2_gdf[combined2_gdf["STATEFP"] == "06"]
california_gdf
# Out:
#                ID   Source  Severity                     Start_Time  \
# 2       A-5006183  Source1         2  2022-08-20 13:13:00.000000000
# 4       A-6690583  Source1         2            2020-12-04 01:46:00
# 13      A-4535214  Source1         2            2022-02-18 16:53:00
# 21      A-1506844  Source3         2            2020-06-15 08:17:29
# 27      A-3983218  Source1         2  2022-03-22 07:22:30.000000000
# ...           ...      ...       ...                            ...
# 499976  A-5927142  Source1         2     2021-04-10 09:09:00.000000
# 499986  A-6955730  Source1         2            2020-11-01 00:05:00
# 499987  A-6935925  Source1         2            2020-10-01 02:54:00
# 499993  A-4757020  Source1         2            2022-02-16 12:39:30
# 499994  A-7376496  Source1         2            2019-11-09 16:02:00
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 2       2022-08-20 15:22:45.000000000  34.661189 -120.492822  34.661189
# ...

# %%
top9counties_gdf = california_gdf[(california_gdf["COUNTYFP"] == "075")
                                  | (california_gdf["COUNTYFP"] == "059")
                                  | (california_gdf["COUNTYFP"] == "037")
                                  | (california_gdf["COUNTYFP"] == "001")
                                  | (california_gdf["COUNTYFP"] == "067")
                                  | (california_gdf["COUNTYFP"] == "081")
                                  | (california_gdf["COUNTYFP"] == "013")
                                  | (california_gdf["COUNTYFP"] == "085")
                                  | (california_gdf["COUNTYFP"] == "073")]
top9counties_gdf
# Out:
#                ID   Source  Severity                     Start_Time  \
# 13      A-4535214  Source1         2            2022-02-18 16:53:00
# 21      A-1506844  Source3         2            2020-06-15 08:17:29
# 27      A-3983218  Source1         2  2022-03-22 07:22:30.000000000
# 31        A-19908  Source2         2            2016-09-13 22:15:22
# 39      A-1542566  Source3         3            2020-03-26 16:25:54
# ...           ...      ...       ...                            ...
# 499973   A-337703  Source2         2            2017-02-21 18:31:42
# 499974  A-6791264  Source1         2            2020-12-15 12:43:30
# 499975  A-1679870  Source2         3            2019-12-26 10:34:13
# 499986  A-6955730  Source1         2            2020-11-01 00:05:00
# 499993  A-4757020  Source1         2            2022-02-16 12:39:30
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 13                2022-02-18 18:59:00  32.771645 -117.161407  32.730856
# ...

# %% [markdown]
# Having cut our data to a mere 14.3% of the rows, let's see how big the GBD file is now.

# %%
top9counties_gdf.to_file("../data/processed/top9counties.gdb", driver="OpenFileGDB")
# Out:
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Severity of type Integer64 will be written as a Float64. To get Integer64, use layer creation option TARGET_ARCGIS_VERSION=ARCGIS_PRO_3_2_OR_LATER
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Distance(mi)' to 'Distance_mi_'
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Temperature(F)' to 'Temperature_F_'
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Wind_Chill(F)' to 'Wind_Chill_F_'
#   ogr_write(
# ...

# %% [markdown]
# The directory `top9counties.gdb` is now 246.4 MB, and the largest file in the directory is still above the 100 MiB file size limit. We should cut our data down even further.

# %%
top5counties_gdf = top9counties_gdf[(top9counties_gdf["COUNTYFP"] == "075")
                                    | (top9counties_gdf["COUNTYFP"] == "059")
                                    | (top9counties_gdf["COUNTYFP"] == "037")
                                    | (top9counties_gdf["COUNTYFP"] == "001")
                                    | (top9counties_gdf["COUNTYFP"] == "067")]
top5counties_gdf
# Out:
#                ID   Source  Severity                     Start_Time  \
# 21      A-1506844  Source3         2            2020-06-15 08:17:29
# 31        A-19908  Source2         2            2016-09-13 22:15:22
# 39      A-1542566  Source3         3            2020-03-26 16:25:54
# 43      A-4152380  Source1         2  2022-12-30 16:40:00.000000000
# 45       A-685944  Source2         2            2022-03-07 17:54:31
# ...           ...      ...       ...                            ...
# 499966    A-77389  Source2         3            2016-09-15 17:32:07
# 499974  A-6791264  Source1         2            2020-12-15 12:43:30
# 499975  A-1679870  Source2         3            2019-12-26 10:34:13
# 499986  A-6955730  Source1         2            2020-11-01 00:05:00
# 499993  A-4757020  Source1         2            2022-02-16 12:39:30
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 21                2020-06-15 08:47:18  34.243271 -118.424461        NaN
# ...

# %%
top5counties_gdf.to_file("../data/processed/top5counties.gdb", driver="OpenFileGDB")
# Out:
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Severity of type Integer64 will be written as a Float64. To get Integer64, use layer creation option TARGET_ARCGIS_VERSION=ARCGIS_PRO_3_2_OR_LATER
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Distance(mi)' to 'Distance_mi_'
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Temperature(F)' to 'Temperature_F_'
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Wind_Chill(F)' to 'Wind_Chill_F_'
#   ogr_write(
# ...

# %% [markdown]
# Unfortunately, we are still at 178.1 MB, above the 100 MiB limit. We need to cut some more.

# %%
top3counties_gdf = top5counties_gdf[(top5counties_gdf["COUNTYFP"] == "075")
                                    | (top5counties_gdf["COUNTYFP"] == "059")
                                    | (top5counties_gdf["COUNTYFP"] == "037")]
top3counties_gdf
# Out:
#                ID   Source  Severity                     Start_Time  \
# 21      A-1506844  Source3         2            2020-06-15 08:17:29
# 39      A-1542566  Source3         3            2020-03-26 16:25:54
# 43      A-4152380  Source1         2  2022-12-30 16:40:00.000000000
# 45       A-685944  Source2         2            2022-03-07 17:54:31
# 49      A-7590183  Source1         3            2018-04-04 01:23:23
# ...           ...      ...       ...                            ...
# 499966    A-77389  Source2         3            2016-09-15 17:32:07
# 499974  A-6791264  Source1         2            2020-12-15 12:43:30
# 499975  A-1679870  Source2         3            2019-12-26 10:34:13
# 499986  A-6955730  Source1         2            2020-11-01 00:05:00
# 499993  A-4757020  Source1         2            2022-02-16 12:39:30
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 21                2020-06-15 08:47:18  34.243271 -118.424461        NaN
# ...

# %%
top3counties_gdf.to_file("../data/processed/top3counties.gdb", driver="OpenFileGDB")
# Out:
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Severity of type Integer64 will be written as a Float64. To get Integer64, use layer creation option TARGET_ARCGIS_VERSION=ARCGIS_PRO_3_2_OR_LATER
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Distance(mi)' to 'Distance_mi_'
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Temperature(F)' to 'Temperature_F_'
#   ogr_write(
# /Users/Arthur/brew/Caskroom/miniforge/base/envs/built-environment/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Wind_Chill(F)' to 'Wind_Chill_F_'
#   ogr_write(
# ...

# %% [markdown]
# Damn, we're still over the limit. Alright, let's just forget about the geometry and save CSVs.

# %%
# top9counties_df = pd.DataFrame(top9counties_gdf.drop(columns="geometry"))
# top9counties_df
# Out:
#                ID   Source  Severity                     Start_Time  \
# 13      A-4535214  Source1         2            2022-02-18 16:53:00
# 21      A-1506844  Source3         2            2020-06-15 08:17:29
# 27      A-3983218  Source1         2  2022-03-22 07:22:30.000000000
# 31        A-19908  Source2         2            2016-09-13 22:15:22
# 39      A-1542566  Source3         3            2020-03-26 16:25:54
# ...           ...      ...       ...                            ...
# 499973   A-337703  Source2         2            2017-02-21 18:31:42
# 499974  A-6791264  Source1         2            2020-12-15 12:43:30
# 499975  A-1679870  Source2         3            2019-12-26 10:34:13
# 499986  A-6955730  Source1         2            2020-11-01 00:05:00
# 499993  A-4757020  Source1         2            2022-02-16 12:39:30
#
#                              End_Time  Start_Lat   Start_Lng    End_Lat  \
# 13                2022-02-18 18:59:00  32.771645 -117.161407  32.730856
# ...

# %%
# top9counties_df.to_csv("../data/processed/top9counties.csv")

# %%
# top5counties_df = pd.DataFrame(top5counties_gdf.drop(columns="geometry"))
# top5counties_df.to_csv("../data/processed/top5counties.csv")

# %%
# top3counties_df = pd.DataFrame(top3counties_gdf.drop(columns="geometry"))
# top3counties_df.to_csv("../data/processed/top3counties.csv")

# %% [markdown]
# Without dropping columns, the CSVs end up being too large, so let's drop some columns that we know we won't use.

# %%
unnecessary_columns = ["ID", 
                       "Source", 
                       "End_Time",
                       "Start_Lat",
                       "Start_Lng",
                       "End_Lat",
                       "End_Lng",
                       "Distance(mi)",
                       "Description",
                       "Street",
                       "City",
                       "County",
                       "State",
                       "Zipcode",
                       "Country",
                       # "Timezone", # We might need Timezone. Not sure if timestamp from Start_Time is UTC, local time, etc.
                       "Airport_Code",
                       "Weather_Timestamp",
                       "Wind_Direction", # We probably don't care about wind direction
                       "GEOID10",
                       "GEOID20",
                       "STATEFP",
                       "COUNTYFP",
                       "TRACTCE",
                       "BLKGRPCE",
                       "CSA",
                       "CSA_Name",
                       "CBSA",
                       "CBSA_Name"
                       ]

top9counties_dropped_df = top9counties_df.drop(columns=unnecessary_columns)
top5counties_dropped_df = top5counties_df.drop(columns=unnecessary_columns)
top3counties_dropped_df = top3counties_df.drop(columns=unnecessary_columns)

top9counties_dropped_df
# Out:
#         Severity                     Start_Time    Timezone  Temperature(F)  \
# 13             2            2022-02-18 16:53:00  US/Pacific            63.0
# 21             2            2020-06-15 08:17:29  US/Pacific            64.0
# 27             2  2022-03-22 07:22:30.000000000  US/Pacific            55.0
# 31             2            2016-09-13 22:15:22  US/Pacific            62.6
# 39             3            2020-03-26 16:25:54  US/Pacific            61.0
# ...          ...                            ...         ...             ...
# 499973         2            2017-02-21 18:31:42  US/Pacific            53.1
# 499974         2            2020-12-15 12:43:30  US/Pacific            73.0
# 499975         3            2019-12-26 10:34:13  US/Pacific            53.0
# 499986         2            2020-11-01 00:05:00  US/Pacific            65.0
# 499993         2            2022-02-16 12:39:30  US/Pacific            63.0
#
# ...

# %% [markdown]
# Let's also drop rows with null values.

# %%
top9counties_dropped_df.dropna(inplace=True)
top5counties_dropped_df.dropna(inplace=True)
top3counties_dropped_df.dropna(inplace=True)

top9counties_dropped_df
# Out:
#         Severity                     Start_Time    Timezone  Temperature(F)  \
# 13             2            2022-02-18 16:53:00  US/Pacific            63.0
# 27             2  2022-03-22 07:22:30.000000000  US/Pacific            55.0
# 39             3            2020-03-26 16:25:54  US/Pacific            61.0
# 43             2  2022-12-30 16:40:00.000000000  US/Pacific            60.0
# 45             2            2022-03-07 17:54:31  US/Pacific            65.0
# ...          ...                            ...         ...             ...
# 499963         2  2023-01-28 18:59:30.000000000  US/Pacific            57.0
# 499965         2  2022-12-22 13:03:00.000000000  US/Pacific            68.0
# 499974         2            2020-12-15 12:43:30  US/Pacific            73.0
# 499975         3            2019-12-26 10:34:13  US/Pacific            53.0
# 499986         2            2020-11-01 00:05:00  US/Pacific            65.0
#
# ...

# %%
top9counties_dropped_df.to_csv("../data/processed/top9counties_dropped.csv")

# %% [markdown]
# Wow, dropping null values cut down on the size a lot, such that `top9counties_dropped.csv` is currently 83.4 MB.
